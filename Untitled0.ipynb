# %%
import folium
from branca.element import Figure
fig3=Figure(width=1000,height=550)
map3 = folium.Map(location=[18.7899882 , 84.413047],tiles='cartodbpositron',zoom_start=8)
fig3.add_child(map3)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
 coords_1=[[16.5062, 80.6480],[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8971, 81.6634],[17.0005, 81.8040 ],
        [16.9341, 81.9555],[17.0500, 82.1679],[17.2789, 82.4013],[17.3573, 82.5443],[17.6896, 83.0024],[17.6970, 83.1466],[17.6868, 83.2185],
        [18.2949, 83.8938],[18.4101, 83.9030],[18.5206, 83.8937],[18.6718, 83.9506],[18.7899882 ,84.413047]]
coords_2=[[16.5062, 80.6480],[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8971, 81.6634],[17.0005, 81.8040 ],
        [16.9341, 81.9555],[17.0500, 82.1679],[17.2789, 82.4013],[17.3573, 82.5443],[17.6896, 83.0024],[17.6970, 83.1466],[17.6868, 83.2185],
        [18.1067, 83.3956],[18.4556, 83.6494],[18.6007, 83.7576],[18.6925, 83.8168],[18.7899882 ,84.413047]]
coords_3=[[16.5062, 80.6480],[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8971, 81.6634],[17.0005, 81.8040 ],
        [16.9341, 81.9555],[17.0500, 82.1679],[17.2789, 82.4013],[17.3573, 82.5443],[17.6896, 83.0024],[17.6970, 83.1466],[17.6868, 83.2185],
        [18.2949, 83.8938],[18.4101, 83.9030],[18.5206, 83.8937],[18.6718, 83.9506],[18.7899882 ,84.413047]]
f1=folium.FeatureGroup("ROUTE1")
f2=folium.FeatureGroup("ROUTE2")
f3=folium.FeatureGroup("ROUTE3")

# Adding lines to the different feature groups
line_1=folium.vector_layers.PolyLine(coords_1,popup='<b>ROUTE1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(coords_2,popup='<b>ROUTE2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
line_3=folium.vector_layers.PolyLine(coords_3,popup='<b>ROUTE3</b>',tooltip='Vehicle_3',color='green',weight=10).add_to(f3)

folium.Marker(location=[18.7899882 ,84.413047],popup='kothuru',tooltip='HOME TOWN',icon=folium.Icon(color='black',prefix='glyphicon',icon='home')).add_to(map3)
folium.Marker(location=[17.6868,83.2185],popup='visakapatnam',tooltip='<strong>"KIMS HOSPITAL"</strong>',icon=folium.Icon(color='pink',prefix='glyphicon',icon='fas fa-plus-square')).add_to(map3)
folium.Marker(location=[18.1067,83.8938],popup='srikakulam',tooltip='<strong>IIIT SRIKAKULAM</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='fas fa-plane')).add_to(map3)
folium.Marker(location=[17.2789,82.4013],popup='annavaram',tooltip="ANNAVARAM TEMPLE",icon=folium.Icon(color='blue',prefix="fa",icon='bell')).add_to(map3)
folium.Marker(location=[16.5062,80.6480],popup='vijaywada',tooltip='VIJAYWADA TEMPLE',icon=folium.Icon(color='green',prefix="fa",icon='plane')).add_to(map3)
folium.Marker(location=[16.7850,80.8488],popup='nuzvid',tooltip='RGUKT NUZVID',icon=folium.Icon(color='purple',prefix='fa',icon='university')).add_to(map3)

f1.add_to(map3)
f2.add_to(map3)
f3.add_to(map3)
folium.LayerControl().add_to(map3)
map3
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
